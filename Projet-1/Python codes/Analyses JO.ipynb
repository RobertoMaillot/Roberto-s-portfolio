# %%
import pandas as pd
df_jeux_all = pd.read_csv("athlete_JO_events.csv")

# %%
df_marathon_men_jo = df_jeux_all[df_jeux_all['Event']=="Athletics Men's Marathon"].reset_index()

# %%
df_marathon_men_jo = df_marathon_men_jo.drop(columns='index')
df_marathon_men_jo
# Out:
#           ID                           Name Sex   Age  Height  Weight  \
# 0        166                 Omari Abdallah   M  21.0   168.0    57.0
# 1        175  Abdelgani Hassan Abdel Fattah   M  31.0     NaN     NaN
# 2        254           Talal Omar Abdillahi   M  25.0   170.0    57.0
# 3        256    Abdihakim "Abdi" Abdirahman   M  35.0   178.0    61.0
# 4        289       Abdul Haji Abdul Latheef   M  17.0   168.0    54.0
# ...      ...                            ...  ..   ...     ...     ...
# 2088  135127                  Darko ivanovi   M  25.0   178.0    64.0
# 2089  135218              Valrijs olnerovis   M  27.0   180.0    67.0
# 2090  135427              Frank Thomas Zuna   M  31.0   175.0    69.0
# 2091  135529         Vlastimil Zwiefelhofer   M  27.0   170.0    63.0
# 2092  135561                  Frantiek Zyka   M  26.0     NaN     NaN
#
#                 Team  NOC        Games  Year  Season       City      Sport  \
# ...

# %%
df_marathon_women_jo = df_jeux_all[df_jeux_all['Event']=="Athletics Women's Marathon"].reset_index()

# %%
df_marathon_women_jo = df_marathon_women_jo.drop(columns='index')
df_marathon_women_jo
# Out:
#          ID                  Name Sex   Age  Height  Weight       Team  NOC  \
# 0        95     Georgia Abatzidou   F  35.0   155.0    43.0     Greece  GRE
# 1       397      Mara Abel Diguez   F  29.0   163.0    46.0      Spain  ESP
# 2       574      rika Abril Surez   F  34.0   164.0    52.0   Colombia  COL
# 3       574      rika Abril Surez   F  38.0   164.0    52.0   Colombia  COL
# 4       929  Berhane Adere Debala   F  35.0   170.0    50.0   Ethiopia  ETH
# ..      ...                   ...  ..   ...     ...     ...        ...  ...
# 740  134789          Zhou Chunxiu   F  25.0   162.0    45.0      China  CHN
# 741  134789          Zhou Chunxiu   F  29.0   162.0    45.0      China  CHN
# 742  134861           Zhu Xiaolin   F  24.0   168.0    50.0      China  CHN
# 743  134861           Zhu Xiaolin   F  28.0   168.0    50.0      China  CHN
# 744  135477          Vaida sinait   F  28.0   167.0    50.0  Lithuania  LTU
#
# ...

# %%
df_marathon_women_jo.to_csv('df_marathon_women_jo.csv')

# %%
df_marathon_men_jo.to_csv('df_marathon_men_jo.csv')
