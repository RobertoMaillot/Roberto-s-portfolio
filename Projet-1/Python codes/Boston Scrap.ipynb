# %%
import pandas as pd

# %%
df = pd.read_csv('https://data.scorenetwork.org/data/boston_marathon_2023.csv')  
df
# Out:
#       age_group  place_overall  place_gender  place_division  \
# 0         18-39              1             1               1
# 1         18-39              2             2               2
# 2         18-39              3             3               3
# 3         18-39              4             4               4
# 4         18-39              5             5               5
# ...         ...            ...           ...             ...
# 26593     75-79          25856         10994               8
# 26594     75-79          26144         11158               9
# 26595     75-79          26203         11188              10
# 26596       80+          25010         10544               1
# 26597       80+          25149         10615               2
#
#                       name   team bib_number   half_time  finish_net  \
# 0            Chebet, Evans  Team–          1   1H 2M 20S   2H 5M 54S
# 1            Geay, Gabriel  Team–          3   1H 2M 20S    2H 6M 4S
# ...

# %%
df.to_csv('results_marathon_boston_2023.csv')

# %%
df_women_win = pd.read_csv('https://storage.googleapis.com/kagglesdsdata/datasets/3112745/5389070/Womens_Boston_Marathon_Winners.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20240304%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240304T144946Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...')  
df_women_win
# Out:
#       Year                  Winner        Country     Time  Distance (Miles)  \
# 0   1966.0              Bobbi Gibb  United States  3:21:40              26.2
# 1   1967.0              Bobbi Gibb  United States  3:27:17              26.2
# 2   1968.0              Bobbi Gibb  United States  3:30:00              26.2
# 3   1969.0         Sara Mae Berman  United States  3:22:46              26.2
# 4   1970.0         Sara Mae Berman  United States  3:05:07              26.2
# 5   1971.0         Sara Mae Berman  United States  3:08:30              26.2
# 6   1972.0            Nina Kuscsik  United States  3:10:26              26.2
# 7   1973.0       Jacqueline Hansen  United States  3:05:59              26.2
# 8   1974.0             Miki Gorman  United States  2:47:11              26.2
# 9   1975.0            Liane Winter        Germany  2:42:24              26.2
# 10  1976.0             Kim Merritt  United States  2:47:10              26.2
# ...

# %%
#https://storage.googleapis.com/kagglesdsdata/datasets/3112745/5389070/Womens_Boston_Marathon_Winners.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20240304%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240304T144946Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...

# %%
df_women_win.to_csv('marathon_boston_women_win.csv')

# %%
df_men_win = pd.read_csv('https://storage.googleapis.com/kagglesdsdata/datasets/3112745/5389070/Mens_Boston_Marathon_Winners.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20240304%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240304T145239Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...')  
df_men_win
# Out:
#        Year              Winner        Country      Time  Distance (Miles)  \
# 0    1897.0      John McDermott  United States  02:55:10              24.5
# 1    1898.0    Ronald MacDonald         Canada  02:42:00              24.5
# 2    1899.0  Lawrence Brignolia  United States  02:54:38              24.5
# 3    1900.0        Jack Caffery         Canada  02:39:44              24.5
# 4    1901.0        Jack Caffery         Canada  02:29:23              24.5
# ..      ...                 ...            ...       ...               ...
# 121  2018.0       Yuki Kawauchi          Japan  02:15:58              26.2
# 122  2019.0    Lawrence Cherono          Kenya  02:07:57              26.2
# 123     NaN                 NaN            NaN       NaN               NaN
# 124  2021.0      Benson Kipruto          Kenya  02:09:51              26.2
# 125  2022.0        Evans Chebet          Kenya  02:06:51              26.2
#
#      Distance (KM)
# 0             39.4
# 1             39.4
# ...

# %%
df_men_win.to_csv('marathon_boston_men_win.csv')

# %%
df_athletes_london_2022 = pd.read_csv('https://storage.googleapis.com/kagglesdsdata/datasets/2600040/4440043/London_2022_elite_results.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20240304%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240304T161248Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...')  
df_athletes_london_2022
# Out:
#     Overall Place  Gender Place  Category Place                         Name  \
# 0               1             1             NaN          KIPRUTO, Amos (KEN)
# 1               2             2             NaN      GEBRESILASE, Leul (ETH)
# 2               3             3             NaN           ABDI, Bashir (BEL)
# 3               4             4             NaN          ATANAW, Kinde (ETH)
# 4               5             5             NaN       BEKELE, Kenenisa (ETH)
# 5               6             6             NaN        LEGESE, Birhanu (ETH)
# 6               7             7             NaN           LEMMA, Sisay (ETH)
# 7               8             8             NaN        ROBINSON, Brett (AUS)
# 8               9             9             NaN  GHEBRESILASIE, Weynay (GBR)
# 9              10            10             NaN       SESEMANN, Philip (GBR)
# 10             11            11             NaN         FUTAOKA, Kohei (JPN)
# ...

# %%
df_athletes_london_2022.to_csv('london_marathon_athletes_2022.csv')
